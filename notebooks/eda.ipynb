# %% [markdown]
# ### Exploratory Data Analysis
# ### Using transaction and behavioral data to uncover risk patterns

# %%
import importlib.util
import sys
import os

eda_utils_path = os.path.abspath(os.path.join("..", "src", "eda_utils..py"))
spec = importlib.util.spec_from_file_location("eda_utils", eda_utils_path)
eda_utils = importlib.util.module_from_spec(spec)
sys.modules["eda_utils"] = eda_utils
spec.loader.exec_module(eda_utils)

# %%
file_path = '../data/data.csv' 
df = eda_utils.load_data(file_path)
df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
# ...

# %% [markdown]
# ### Dataset Overview

# %%
eda_utils.dataset_overview(df)
# Out:
# Shape: (95662, 16)
#
# Columns and Data Types:
#  TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# CurrencyCode             object
# CountryCode               int64
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object
#
# First 5 Rows:
#           TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# ...

# %%
eda_utils.summary_statistics(df)
# Out:
# Summary Statistics:
#         CountryCode        Amount         Value  PricingStrategy   FraudResult
# count      95662.0  9.566200e+04  9.566200e+04     95662.000000  95662.000000
# mean         256.0  6.717846e+03  9.900584e+03         2.255974      0.002018
# std            0.0  1.233068e+05  1.231221e+05         0.732924      0.044872
# min          256.0 -1.000000e+06  2.000000e+00         0.000000      0.000000
# 25%          256.0 -5.000000e+01  2.750000e+02         2.000000      0.000000
# 50%          256.0  1.000000e+03  1.000000e+03         2.000000      0.000000
# 75%          256.0  2.800000e+03  5.000000e+03         2.000000      0.000000
# max          256.0  9.880000e+06  9.880000e+06         4.000000      1.000000

# %% [markdown]
# ### Numerical Features Distribution

# %%
numerical_cols = ['Amount', 'Value']
eda_utils.plot_numerical_distribution(df, numerical_cols)

# %% [markdown]
# ### categorical features distribution

# %%
categorical_cols = [
    'CurrencyCode', 'CountryCode', 'ProviderId', 'ProductCategory',
    'ChannelId', 'PricingStrategy', 'FraudResult'
]
eda_utils.plot_categorical_distribution(df, categorical_cols)

# %% [markdown]
# ### Correlation Heatmap

# %%
eda_utils.correlation_heatmap(df, numerical_cols)

# %%
eda_utils.missing_value_analysis(df)
# Out:
# Missing Values:
#  TransactionId           0
# BatchId                 0
# AccountId               0
# SubscriptionId          0
# CustomerId              0
# CurrencyCode            0
# CountryCode             0
# ProviderId              0
# ProductId               0
# ProductCategory         0
# ChannelId               0
# Amount                  0
# Value                   0
# TransactionStartTime    0
# PricingStrategy         0
# FraudResult             0
# dtype: int64

# %% [markdown]
# ### Outliers Analysis

# %%
eda_utils.boxplot_outlier_detection(df, numerical_cols)
